# %%
#CLUSTERING IN PYTHON(implementation)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#read the geographical images
img1= mpimg.imread("C:/Users/dheer/Downloads/gtr.jpg")

img2= mpimg.imread("C:/Users/dheer/Downloads/solo1.jpg")

#zoom in for better recognition 
img11= img1[120:200,100:200,:]
img22= img2[120:200,100:200,:]

# %%
boxsize=15
f= plt.figure(figsize=(boxsize,0.70*boxsize))

plt1=plt.subplot(1,4,1)
plt1.imshow(img1)
plt.title('figure 1 :2000',fontsize=15)
plt.xticks([])
plt.yticks([])

plt2=plt.subplot(1,4,2)
plt2.imshow(img2)
plt.title('figure 2 :2000',fontsize=15)
plt.xticks([])
plt.yticks([])

plt3=plt.subplot(1,4,3)
plt3.imshow(img11)
plt.title('figure 1 zoomed',fontsize=15)
plt.xticks([])
plt.yticks([])

plt4=plt.subplot(1,4,4)
plt4.imshow(img22)
plt.title('figure 2 zoomed',fontsize=15)
plt.xticks([])
plt.yticks([])

f.tight_layout()
plt.show()
